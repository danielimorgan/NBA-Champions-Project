# %% [markdown]
# # NBA Champions 2000-2019 CSV Modifications

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# Load file
champs_data_loading = Path("NBA Champions 2000-2019.csv")

# Read file
champs_data = pd.read_csv(champs_data_loading)

# Show file

champs_data
# Out:
#          Year               Champion Abbreviation
# 0   2018-2019        Toronto Raptors          TOR
# 1   2017-2018  Golden State Warriors          GSW
# 2   2016-2017  Golden State Warriors          GSW
# 3   2015-2016    Cleveland Cavaliers          CLE
# 4   2014-2015  Golden State Warriors          GSW
# 5   2013-2014      San Antonio Spurs          SAS
# 6   2012-2013             Miami Heat          MIA
# 7   2011-2012             Miami Heat          MIA
# 8   2010-2011       Dallas Mavericks          DAL
# 9   2009-2010     Los Angeles Lakers          LAL
# 10  2008-2009     Los Angeles Lakers          LAL
# 11  2007-2008         Boston Celtics          BOS
# 12  2006-2007      San Antonio Spurs          SAS
# 13  2005-2006             Miami Heat          MIA
# 14  2004-2005      San Antonio Spurs          SAS
# 15  2003-2004        Detroit Pistons          DET
# 16  2002-2003      San Antonio Spurs          SAS
# 17  2001-2002     Los Angeles Lakers          LAL
# ...

# %%
#Reindex
champs_data_clean = champs_data.set_index('Year')

champs_data_clean.head()
# Out:
#                         Champion Abbreviation
# Year
# 2018-2019        Toronto Raptors          TOR
# 2017-2018  Golden State Warriors          GSW
# 2016-2017  Golden State Warriors          GSW
# 2015-2016    Cleveland Cavaliers          CLE
# 2014-2015  Golden State Warriors          GSW

# %%
# Export to file.

champs_data_clean.to_csv("Data Mods/Revised NBA Champions.csv")
